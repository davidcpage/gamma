# %%
from gamma import *

testcase = namedtuple('testcase', ('graph', 'rule', 'result'))

def run(testcase):
    draw(testcase.graph)
    draw(testcase.rule)
    res = apply_rule(testcase.graph, testcase.rule)
    draw(res)
    assert(res) == testcase.result

# %% [markdown]
# #### Test 1: remove nodes

# %%
make_node = lambda t, params={}: {'type': t, 'params': params}
identity = make_node("Identity", {'important': False})
important_identity = make_node('Identity', {'important': True})


@bind_vars
def remove_identities(name, _in):
    LHS = {name: (identity, [_in])}
    RHS = {}
    redirects = (name, _in)
    return LHS, RHS, redirects

g = pipeline([
    ('A', identity, ['input']),
    ('B', identity),
    ('C', make_node('Type_A')),
    ('D', identity),
    ('E', identity, ['C']),
    ('F', identity),
    ('G', identity),
    ('H', make_node('Type_B')),
    ('I', identity),
    ('J', important_identity),
    ('K', identity, ['H']),
    ('L', make_node('Type_C'), ['I'])
], prefix='scope')

res = {
    'scope/C': ({'type': 'Type_A', 'params': {}}, ['input']),
    'scope/H': ({'type': 'Type_B', 'params': {}}, ['scope/C']),
    'scope/J': ({'type': 'Identity', 'params': {'important': True}}, ['scope/H']),
    'scope/L': ({'type': 'Type_C', 'params': {}}, ['scope/H'])
}
run(testcase(g, remove_identities(), res))
# Out:
# <div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#8dd3c7;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Identity</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#ffffb3;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Type_A</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#bebada;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Type_B</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#fb8072;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Type_C</div></div><div style="min-width: 349pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="349pt" height="60pt"
#  viewBox="0.00 0.00 349.00 59.74" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.393018 0.393018) rotate(0) translate(4 148)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-148 884,-148 884,4 -4,4"/>
# <g id="clust1" class="cluster"><title>cluster_scope</title>
# <path fill="#777777" fill-opacity="0.266667" stroke="black" d="M94,-8C94,-8 860,-8 860,-8 866,-8 872,-14 872,-20 872,-20 872,-124 872,-124 872,-130 866,-136 860,-136 860,-136 94,-136 94,-136 88,-136 82,-130 82,-124 82,-124 82,-20 82,-20 82,-14 88,-8 94,-8"/>
# <text text-anchor="middle" x="477" y="-120.8" font-family="Times,serif" font-size="14.00">scope</text>
# </g>
# <!-- scope/A -->
# <g id="node1" class="node"><title>scope/A</title>
# <g id="a_node1"><a xlink:title="scope/A Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M132,-79C132,-79 102,-79 102,-79 96,-79 90,-73 90,-67 90,-67 90,-55 90,-55 90,-49 96,-43 102,-43 102,-43 132,-43 132,-43 138,-43 144,-49 144,-55 144,-55 144,-67 144,-67 144,-73 138,-79 132,-79"/>
# <text text-anchor="middle" x="117" y="-56.8" font-family="Times,serif" font-size="14.00">A</text>
# </a>
# </g>
# </g>
# <!-- scope/B -->
# <g id="node2" class="node"><title>scope/B</title>
# <g id="a_node2"><a xlink:title="scope/B Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M222,-79C222,-79 192,-79 192,-79 186,-79 180,-73 180,-67 180,-67 180,-55 180,-55 180,-49 186,-43 192,-43 192,-43 222,-43 222,-43 228,-43 234,-49 234,-55 234,-55 234,-67 234,-67 234,-73 228,-79 222,-79"/>
# <text text-anchor="middle" x="207" y="-56.8" font-family="Times,serif" font-size="14.00">B</text>
# </a>
# </g>
# </g>
# <!-- scope/A&#45;&gt;scope/B -->
# <g id="edge2" class="edge"><title>scope/A&#45;&gt;scope/B</title>
# <path fill="none" stroke="black" d="M144.403,-61C152.393,-61 161.311,-61 169.824,-61"/>
# <polygon fill="black" stroke="black" points="169.919,-64.5001 179.919,-61 169.919,-57.5001 169.919,-64.5001"/>
# </g>
# <!-- scope/C -->
# <g id="node3" class="node"><title>scope/C</title>
# <g id="a_node3"><a xlink:title="scope/C Type_A {}">
# <path fill="#ffffb3" stroke="black" d="M312,-79C312,-79 282,-79 282,-79 276,-79 270,-73 270,-67 270,-67 270,-55 270,-55 270,-49 276,-43 282,-43 282,-43 312,-43 312,-43 318,-43 324,-49 324,-55 324,-55 324,-67 324,-67 324,-73 318,-79 312,-79"/>
# <text text-anchor="middle" x="297" y="-56.8" font-family="Times,serif" font-size="14.00">C</text>
# </a>
# </g>
# </g>
# <!-- scope/B&#45;&gt;scope/C -->
# <g id="edge3" class="edge"><title>scope/B&#45;&gt;scope/C</title>
# <path fill="none" stroke="black" d="M234.403,-61C242.393,-61 251.311,-61 259.824,-61"/>
# <polygon fill="black" stroke="black" points="259.919,-64.5001 269.919,-61 259.919,-57.5001 259.919,-64.5001"/>
# </g>
# <!-- scope/D -->
# <g id="node4" class="node"><title>scope/D</title>
# <g id="a_node4"><a xlink:title="scope/D Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M402,-52C402,-52 372,-52 372,-52 366,-52 360,-46 360,-40 360,-40 360,-28 360,-28 360,-22 366,-16 372,-16 372,-16 402,-16 402,-16 408,-16 414,-22 414,-28 414,-28 414,-40 414,-40 414,-46 408,-52 402,-52"/>
# <text text-anchor="middle" x="387" y="-29.8" font-family="Times,serif" font-size="14.00">D</text>
# </a>
# </g>
# </g>
# <!-- scope/C&#45;&gt;scope/D -->
# <g id="edge4" class="edge"><title>scope/C&#45;&gt;scope/D</title>
# <path fill="none" stroke="black" d="M324.403,-52.8991C332.481,-50.4206 341.507,-47.6514 350.105,-45.0134"/>
# <polygon fill="black" stroke="black" points="351.386,-48.2815 359.919,-42.0021 349.332,-41.5894 351.386,-48.2815"/>
# </g>
# <!-- scope/E -->
# <g id="node5" class="node"><title>scope/E</title>
# <g id="a_node5"><a xlink:title="scope/E Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M402,-106C402,-106 372,-106 372,-106 366,-106 360,-100 360,-94 360,-94 360,-82 360,-82 360,-76 366,-70 372,-70 372,-70 402,-70 402,-70 408,-70 414,-76 414,-82 414,-82 414,-94 414,-94 414,-100 408,-106 402,-106"/>
# <text text-anchor="middle" x="387" y="-83.8" font-family="Times,serif" font-size="14.00">E</text>
# </a>
# </g>
# </g>
# <!-- scope/C&#45;&gt;scope/E -->
# <g id="edge5" class="edge"><title>scope/C&#45;&gt;scope/E</title>
# <path fill="none" stroke="black" d="M324.403,-69.1009C332.481,-71.5794 341.507,-74.3486 350.105,-76.9866"/>
# <polygon fill="black" stroke="black" points="349.332,-80.4106 359.919,-79.9979 351.386,-73.7185 349.332,-80.4106"/>
# </g>
# <!-- scope/F -->
# <g id="node6" class="node"><title>scope/F</title>
# <g id="a_node6"><a xlink:title="scope/F Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M492,-106C492,-106 462,-106 462,-106 456,-106 450,-100 450,-94 450,-94 450,-82 450,-82 450,-76 456,-70 462,-70 462,-70 492,-70 492,-70 498,-70 504,-76 504,-82 504,-82 504,-94 504,-94 504,-100 498,-106 492,-106"/>
# <text text-anchor="middle" x="477" y="-83.8" font-family="Times,serif" font-size="14.00">F</text>
# </a>
# </g>
# </g>
# <!-- scope/E&#45;&gt;scope/F -->
# <g id="edge6" class="edge"><title>scope/E&#45;&gt;scope/F</title>
# <path fill="none" stroke="black" d="M414.403,-88C422.393,-88 431.311,-88 439.824,-88"/>
# <polygon fill="black" stroke="black" points="439.919,-91.5001 449.919,-88 439.919,-84.5001 439.919,-91.5001"/>
# </g>
# <!-- scope/G -->
# <g id="node7" class="node"><title>scope/G</title>
# <g id="a_node7"><a xlink:title="scope/G Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M582,-106C582,-106 552,-106 552,-106 546,-106 540,-100 540,-94 540,-94 540,-82 540,-82 540,-76 546,-70 552,-70 552,-70 582,-70 582,-70 588,-70 594,-76 594,-82 594,-82 594,-94 594,-94 594,-100 588,-106 582,-106"/>
# <text text-anchor="middle" x="567" y="-83.8" font-family="Times,serif" font-size="14.00">G</text>
# </a>
# </g>
# </g>
# <!-- scope/F&#45;&gt;scope/G -->
# <g id="edge7" class="edge"><title>scope/F&#45;&gt;scope/G</title>
# <path fill="none" stroke="black" d="M504.403,-88C512.393,-88 521.311,-88 529.824,-88"/>
# <polygon fill="black" stroke="black" points="529.919,-91.5001 539.919,-88 529.919,-84.5001 529.919,-91.5001"/>
# </g>
# <!-- scope/H -->
# <g id="node8" class="node"><title>scope/H</title>
# <g id="a_node8"><a xlink:title="scope/H Type_B {}">
# <path fill="#bebada" stroke="black" d="M672,-106C672,-106 642,-106 642,-106 636,-106 630,-100 630,-94 630,-94 630,-82 630,-82 630,-76 636,-70 642,-70 642,-70 672,-70 672,-70 678,-70 684,-76 684,-82 684,-82 684,-94 684,-94 684,-100 678,-106 672,-106"/>
# <text text-anchor="middle" x="657" y="-83.8" font-family="Times,serif" font-size="14.00">H</text>
# </a>
# </g>
# </g>
# <!-- scope/G&#45;&gt;sc
# <div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#8dd3c7;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Identity</div></div><div style="min-width: 61pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="61pt" height="18pt"
#  viewBox="0.00 0.00 61.00 17.66" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.401316 0.401316) rotate(0) translate(4 40)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-40 148,-40 148,4 -4,4"/>
# <!-- _name -->
# <g id="node1" class="node"><title>_name</title>
# <g id="a_node1"><a xlink:title="_name Identity {&#39;important&#39;: False}">
# <path fill="#8dd3c7" stroke="black" d="M132,-36C132,-36 102,-36 102,-36 96,-36 90,-30 90,-24 90,-24 90,-12 90,-12 90,-6 96,-0 102,-0 102,-0 132,-0 132,-0 138,-0 144,-6 144,-12 144,-12 144,-24 144,-24 144,-30 138,-36 132,-36"/>
# <text text-anchor="middle" x="117" y="-13.8" font-family="Times,serif" font-size="14.00">_name</text>
# </a>
# </g>
# </g>
# <!-- __in -->
# <g id="node2" class="node"><title>__in</title>
# <path fill="#ffffff" stroke="black" d="M42,-36C42,-36 12,-36 12,-36 6,-36 0,-30 0,-24 0,-24 0,-12 0,-12 0,-6 6,-0 12,-0 12,-0 42,-0 42,-0 48,-0 54,-6 54,-12 54,-12 54,-24 54,-24 54,-30 48,-36 42,-36"/>
# <text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">__in</text>
# </g>
# <!-- __in&#45;&gt;_name -->
# <g id="edge1" class="edge"><title>__in&#45;&gt;_name</title>
# <path fill="none" stroke="black" d="M54.4029,-18C62.3932,-18 71.3106,-18 79.8241,-18"/>
# <polygon fill="black" stroke="black" points="79.919,-21.5001 89.919,-18 79.919,-14.5001 79.919,-21.5001"/>
# </g>
# </g>
# </svg>
# </div>
# <div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#ffffb3;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Type_A</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#bebada;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Type_B</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#8dd3c7;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Identity</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#fb8072;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Type_C</div></div><div style="min-width: 133pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="133pt" height="58pt"
#  viewBox="0.00 0.00 133.00 58.09" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.382184 0.382184) rotate(0) translate(4 148)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-148 344,-148 344,4 -4,4"/>
# <g id="clust1" class="cluster"><title>cluster_scope</title>
# <path fill="#777777" fill-opacity="0.266667" stroke="black" d="M94,-8C94,-8 320,-8 320,-8 326,-8 332,-14 332,-20 332,-20 332,-124 332,-124 332,-130 326,-136 320,-136 320,-136 94,-136 94,-136 88,-136 82,-130 82,-124 82,-124 82,-20 82,-20 82,-14 88,-8 94,-8"/>
# <text text-anchor="middle" x="207" y="-120.8" font-family="Times,serif" font-size="14.00">scope</text>
# </g>
# <!-- scope/C -->
# <g id="node1" class="node"><title>scope/C</title>
# <g id="a_node1"><a xlink:title="scope/C Type_A {}">
# <path fill="#ffffb3" stroke="black" d="M132,-79C132,-79 102,-79 102,-79 96,-79 90,-73 90,-67 90,-67 90,-55 90,-55 90,-49 96,-43 102,-43 102,-43 132,-43 132,-43 138,-43 144,-49 144,-55 144,-55 144,-67 144,-67 144,-73 138,-79 132,-79"/>
# <text text-anchor="middle" x="117" y="-56.8" font-family="Times,serif" font-size="14.00">C</text>
# </a>
# </g>
# </g>
# <!-- scope/H -->
# <g id="node2" class="node"><title>scope/H</title>
# <g id="a_node2"><a xlink:title="scope/H Type_B {}">
# <path fill="#bebada" stroke="black" d="M222,-79C222,-79 192,-79 192,-79 186,-79 180,-73 180,-67 180,-67 180,-55 180,-55 180,-49 186,-43 192,-43 192,-43 222,-43 222,-43 228,-43 234,-49 234,-55 234,-55 234,-67 234,-67 234,-73 228,-79 222,-79"/>
# <text text-anchor="middle" x="207" y="-56.8" font-family="Times,serif" font-size="14.00">H</text>
# </a>
# </g>
# </g>
# <!-- scope/C&#45;&gt;scope/H -->
# <g id="edge2" class="edge"><title>scope/C&#45;&gt;scope/H</title>
# <path fill="none" stroke="black" d="M144.403,-61C152.393,-61 161.311,-61 169.824,-61"/>
# <polygon fill="black" stroke="black" points="169.919,-64.5001 179.919,-61 169.919,-57.5001 169.919,-64.5001"/>
# </g>
# <!-- scope/J -->
# <g id="node3" class="node"><title>scope/J</title>
# <g id="a_node3"><a xlink:title="scope/J Identity {&#39;important&#39;: True}">
# <path fill="#8dd3c7" stroke="black" d="M312,-52C312,-52 282,-52 282,-52 276,-52 270,-46 270,-40 270,-40 270,-28 270,-28 270,-22 276,-16 282,-16 282,-16 312,-16 312,-16 318,-16 324,-22 324,-28 324,-28 324,-40 324,-40 324,-46 318,-52 312,-52"/>
# <text text-anchor="middle" x="297" y="-29.8" font-family="Times,serif" font-size="14.00">J</text>
# </a>
# </g>
# </g>
# <!-- scope/H&#45;&gt;scope/J -->
# <g id="edge3" class="edge"><title>scope/H&#45;&gt;scope/J</title>
# <path fill="none" stroke="black" d="M234.403,-52.8991C242.481,-50.4206 251.507,-47.6514 260.105,-45.0134"/>
# <polygon fill="black" stroke="black" points="261.386,-48.2815 269.919,-42.0021 259.332,-41.5894 261.386,-48.2815"/>
# </g>
# <!-- scope/L -->
# <g id="node4" class="node"><title>scope/L</title>
# <g id="a_node4"><a xlink:title="scope/L Type_C {}">
# <path fill="#fb8072" stroke="black" d="M312,-106C312,-106 282,-106 282,-106 276,-106 270,-100 270,-94 270,-94 270,-82 270,-82 270,-76 276,-70 282,-70 282,-70 312,-70 312,-70 318,-70 324,-76 324,-82 324,-82 324,-94 324,-94 324,-100 318,-106 312,-106"/>
# <text text-anchor="middle" x="297" y="-83.8" font-family="Times,serif" font-size="14.00">L</text>
# </a>
# </g>
# </g>
# <!-- scope/H&#45;&gt;scope/L -->
# <g id="edge4" class="edge"><title>scope/H&#45;&gt;scope/L</title>
# <path fill="none" stroke="black" d="M234.403,-69.1009C242.481,-71.5794 251.507,-74.3486 260.105,-76.9866"/>
# <polygon fill="black" stroke="black" points="259.332,-80.4106 269.919,-79.9979 261.386,-73.7185 259.332,-80.4106"/>
# </g>
# <!-- input -->
# <g id="node5" class="node"><title>input</title>
# <path fill="#ffffff" stroke="black" d="M42,-79C42,-79 12,-79 12,-79 6,-79 0,-73 0,-67 0,-67 0,-55 0,-55 0,-49 6,-43 12,-43 12,-43 42,-43 42,-43 48,-43 54,-49 54,-55 54,-55 54,-67 54,-67 54,-73 48,-79 42,-79"/>
# <text text-anchor="middle" x="27" y="-56.8" font-family="Times,serif" font-size="14.00">input</text>
# </g>
# <!-- input&#45;&gt;scope/C -->
# <g id="edge1" class="edge"><title>input&#45;&gt;scope/C</title>
# <path fill="none" stroke="black" d="M54.4029,-61C62.3932,-61 71.3106,-61 79.8241,-61"/>
# <polygon fill="black" stroke="black" points="79.919,-64.5001 89.919,-61 79.919,-57.5001 79.919,-64.5001"/>
# </g>
# </g>
# </svg>
# </div>

# %% [markdown]
# #### Test 2: match with dangling edges

# %%
add = {'type': 'Add', 'params': {}}
scale= {'type': 'Scale', 'params': {}}
add_scale = {'type': 'AddScale', 'params': {}}

@bind_vars
def fuse_add_scale(add_name, scale_name, input_name):
    LHS = pipeline([
        (add_name, add, [input_name]),
        (scale_name, scale)
    ])
    RHS = {path(scale_name, 'fused'): (add_scale, [input_name])}
    return LHS, RHS, (scale_name, path(scale_name, 'fused'))

g = pipeline([
    ('A', add, ['input']),
    ('B', scale),
    ('C', add),
    ('D', add, ['A']),
    ('E', scale)
])

res = {
    'A': ({'type': 'Add', 'params': {}}, ['input']),
    'B': ({'type': 'Scale', 'params': {}}, ['A']),
    'C': ({'type': 'Add', 'params': {}}, ['B']),
    'E/fused': ({'type': 'AddScale', 'params': {}}, ['A'])
}

run(testcase(g, fuse_add_scale(), res))
# Out:
# <div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#80b1d3;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Add</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#fdb462;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Scale</div></div><div style="min-width: 133pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="133pt" height="39pt"
#  viewBox="0.00 0.00 133.00 39.26" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.400602 0.400602) rotate(0) translate(4 94)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-94 328,-94 328,4 -4,4"/>
# <!-- A -->
# <g id="node1" class="node"><title>A</title>
# <g id="a_node1"><a xlink:title="A Add {}">
# <path fill="#80b1d3" stroke="black" d="M132,-63C132,-63 102,-63 102,-63 96,-63 90,-57 90,-51 90,-51 90,-39 90,-39 90,-33 96,-27 102,-27 102,-27 132,-27 132,-27 138,-27 144,-33 144,-39 144,-39 144,-51 144,-51 144,-57 138,-63 132,-63"/>
# <text text-anchor="middle" x="117" y="-40.8" font-family="Times,serif" font-size="14.00">A</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node2" class="node"><title>B</title>
# <g id="a_node2"><a xlink:title="B Scale {}">
# <path fill="#fdb462" stroke="black" d="M222,-90C222,-90 192,-90 192,-90 186,-90 180,-84 180,-78 180,-78 180,-66 180,-66 180,-60 186,-54 192,-54 192,-54 222,-54 222,-54 228,-54 234,-60 234,-66 234,-66 234,-78 234,-78 234,-84 228,-90 222,-90"/>
# <text text-anchor="middle" x="207" y="-67.8" font-family="Times,serif" font-size="14.00">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge2" class="edge"><title>A&#45;&gt;B</title>
# <path fill="none" stroke="black" d="M144.403,-53.1009C152.481,-55.5794 161.507,-58.3486 170.105,-60.9866"/>
# <polygon fill="black" stroke="black" points="169.332,-64.4106 179.919,-63.9979 171.386,-57.7185 169.332,-64.4106"/>
# </g>
# <!-- D -->
# <g id="node4" class="node"><title>D</title>
# <g id="a_node4"><a xlink:title="D Add {}">
# <path fill="#80b1d3" stroke="black" d="M222,-36C222,-36 192,-36 192,-36 186,-36 180,-30 180,-24 180,-24 180,-12 180,-12 180,-6 186,-0 192,-0 192,-0 222,-0 222,-0 228,-0 234,-6 234,-12 234,-12 234,-24 234,-24 234,-30 228,-36 222,-36"/>
# <text text-anchor="middle" x="207" y="-13.8" font-family="Times,serif" font-size="14.00">D</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;D -->
# <g id="edge4" class="edge"><title>A&#45;&gt;D</title>
# <path fill="none" stroke="black" d="M144.403,-36.8991C152.481,-34.4206 161.507,-31.6514 170.105,-29.0134"/>
# <polygon fill="black" stroke="black" points="171.386,-32.2815 179.919,-26.0021 169.332,-25.5894 171.386,-32.2815"/>
# </g>
# <!-- C -->
# <g id="node3" class="node"><title>C</title>
# <g id="a_node3"><a xlink:title="C Add {}">
# <path fill="#80b1d3" stroke="black" d="M312,-90C312,-90 282,-90 282,-90 276,-90 270,-84 270,-78 270,-78 270,-66 270,-66 270,-60 276,-54 282,-54 282,-54 312,-54 312,-54 318,-54 324,-60 324,-66 324,-66 324,-78 324,-78 324,-84 318,-90 312,-90"/>
# <text text-anchor="middle" x="297" y="-67.8" font-family="Times,serif" font-size="14.00">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g id="edge3" class="edge"><title>B&#45;&gt;C</title>
# <path fill="none" stroke="black" d="M234.403,-72C242.393,-72 251.311,-72 259.824,-72"/>
# <polygon fill="black" stroke="black" points="259.919,-75.5001 269.919,-72 259.919,-68.5001 259.919,-75.5001"/>
# </g>
# <!-- E -->
# <g id="node5" class="node"><title>E</title>
# <g id="a_node5"><a xlink:title="E Scale {}">
# <path fill="#fdb462" stroke="black" d="M312,-36C312,-36 282,-36 282,-36 276,-36 270,-30 270,-24 270,-24 270,-12 270,-12 270,-6 276,-0 282,-0 282,-0 312,-0 312,-0 318,-0 324,-6 324,-12 324,-12 324,-24 324,-24 324,-30 318,-36 312,-36"/>
# <text text-anchor="middle" x="297" y="-13.8" font-family="Times,serif" font-size="14.00">E</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;E -->
# <g id="edge5" class="edge"><title>D&#45;&gt;E</title>
# <path fill="none" stroke="black" d="M234.403,-18C242.393,-18 251.311,-18 259.824,-18"/>
# <polygon fill="black" stroke="black" points="259.919,-21.5001 269.919,-18 259.919,-14.5001 259.919,-21.5001"/>
# </g>
# <!-- input -->
# <g id="node6" class="node"><title>input</title>
# <path fill="#ffffff" stroke="black" d="M42,-63C42,-63 12,-63 12,-63 6,-63 0,-57 0,-51 0,-51 0,-39 0,-39 0,-33 6,-27 12,-27 12,-27 42,-27 42,-27 48,-27 54,-33 54,-39 54,-39 54,-51 54,-51 54,-57 48,-63 42,-63"/>
# <text text-anchor="middle" x="27" y="-40.8" font-family="Times,serif" font-size="14.00">input</text>
# </g>
# <!-- input&#45;&gt;A -->
# <g id="edge1" class="edge"><title>input&#45;&gt;A</title>
# <path fill="none" stroke="black" d="M54.4029,-45C62.3932,-45 71.3106,-45 79.8241,-45"/>
# <polygon fill="black" stroke="black" points="79.919,-48.5001 89.919,-45 79.919,-41.5001 79.919,-48.5001"/>
# </g>
# </g>
# </svg>
# </div>
# <div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#80b1d3;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Add</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#fdb462;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Scale</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#b3de69;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">AddScale</div></div><div style="min-width: 97pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="97pt" height="13pt"
#  viewBox="0.00 0.00 97.00 12.63" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.287046 0.287046) rotate(0) translate(4 40)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-40 333.925,-40 333.925,4 -4,4"/>
# <!-- _add_name -->
# <g id="node1" class="node"><title>_add_name</title>
# <g id="a_node1"><a xlink:title="_add_name Add {}">
# <path fill="#80b1d3" stroke="black" d="M193.395,-36C193.395,-36 137.33,-36 137.33,-36 131.33,-36 125.33,-30 125.33,-24 125.33,-24 125.33,-12 125.33,-12 125.33,-6 131.33,-0 137.33,-0 137.33,-0 193.395,-0 193.395,-0 199.395,-0 205.395,-6 205.395,-12 205.395,-12 205.395,-24 205.395,-24 205.395,-30 199.395,-36 193.395,-36"/>
# <text text-anchor="middle" x="165.362" y="-13.8" font-family="Times,serif" font-size="14.00">_add_name</text>
# </a>
# </g>
# </g>
# <!-- _scale_name -->
# <g id="node2" class="node"><title>_scale_name</title>
# <g id="a_node2"><a xlink:title="_scale_name Scale {}">
# <path fill="#fdb462" stroke="black" d="M318.074,-36C318.074,-36 253.479,-36 253.479,-36 247.479,-36 241.479,-30 241.479,-24 241.479,-24 241.479,-12 241.479,-12 241.479,-6 247.479,-0 253.479,-0 253.479,-0 318.074,-0 318.074,-0 324.074,-0 330.074,-6 330.074,-12 330.074,-12 330.074,-24 330.074,-24 330.074,-30 324.074,-36 318.074,-36"/>
# <text text-anchor="middle" x="285.776" y="-13.8" font-family="Times,serif" font-size="14.00">_scale_name</text>
# </a>
# </g>
# </g>
# <!-- _add_name&#45;&gt;_scale_name -->
# <g id="edge2" class="edge"><title>_add_name&#45;&gt;_scale_name</title>
# <path fill="none" stroke="black" d="M205.464,-18C213.695,-18 222.515,-18 231.173,-18"/>
# <polygon fill="black" stroke="black" points="231.218,-21.5001 241.218,-18 231.218,-14.5001 231.218,-21.5001"/>
# </g>
# <!-- _input_name -->
# <g id="node3" class="node"><title>_input_name</title>
# <path fill="#ffffff" stroke="black" d="M77.1451,-36C77.1451,-36 11.9516,-36 11.9516,-36 5.95161,-36 -0.0483924,-30 -0.0483924,-24 -0.0483924,-24 -0.0483924,-12 -0.0483924,-12 -0.0483924,-6 5.95161,-0 11.9516,-0 11.9516,-0 77.1451,-0 77.1451,-0 83.1451,-0 89.1451,-6 89.1451,-12 89.1451,-12 89.1451,-24 89.1451,-24 89.1451,-30 83.1451,-36 77.1451,-36"/>
# <text text-anchor="middle" x="44.5483" y="-13.8" font-family="Times,serif" font-size="14.00">_input_name</text>
# </g>
# <!-- _input_name&#45;&gt;_add_name -->
# <g id="edge1" class="edge"><title>_input_name&#45;&gt;_add_name</title>
# <path fill="none" stroke="black" d="M89.1156,-18C97.4967,-18 106.332,-18 114.884,-18"/>
# <polygon fill="black" stroke="black" points="115.126,-21.5001 125.126,-18 115.126,-14.5001 115.126,-21.5001"/>
# </g>
# </g>
# </svg>
# </div><div style="min-width: 61pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="61pt" height="28pt"
#  viewBox="0.00 0.00 61.00 28.05" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.286255 0.286255) rotate(0) translate(4 94)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-94 209.097,-94 209.097,4 -4,4"/>
# <g id="clust1" class="cluster"><title>cluster__scale_name</title>
# <path fill="#777777" fill-opacity="0.266667" stroke="black" d="M129.097,-8C129.097,-8 193.097,-8 193.097,-8 199.097,-8 205.097,-14 205.097,-20 205.097,-20 205.097,-70 205.097,-70 205.097,-76 199.097,-82 193.097,-82 193.097,-82 129.097,-82 129.097,-82 123.097,-82 117.097,-76 117.097,-70 117.097,-70 117.097,-20 117.097,-20 117.097,-14 123.097,-8 129.097,-8"/>
# <text text-anchor="middle" x="161.097" y="-66.8" font-family="Times,serif" font-size="14.00">_scale_name</text>
# </g>
# <!-- Path(x=_scale_name, y=&#39;fused&#39;) -->
# <g id="node1" class="node"><title>Path(x=_scale_name, y=&#39;fused&#39;)</title>
# <g id="a_node1"><a xlink:title="Path(x=_scale_name, y=&#39;fused&#39;) AddScale {}">
# <path fill="#b3de69" stroke="black" d="M176.097,-52C176.097,-52 146.097,-52 146.097,-52 140.097,-52 134.097,-46 134.097,-40 134.097,-40 134.097,-28 134.097,-28 134.097,-22 140.097,-16 146.097,-16 146.097,-16 176.097,-16 176.097,-16 182.097,-16 188.097,-22 188.097,-28 188.097,-28 188.097,-40 188.097,-40 188.097,-46 182.097,-52 176.097,-52"/>
# <text text-anchor="middle" x="161.097" y="-29.8" font-family="Times,serif" font-size="14.00">fused</text>
# </a>
# </g>
# </g>
# <!-- _input_name -->
# <g id="node2" class="node"><title>_input_name</title>
# <path fill="#ffffff" stroke="black" d="M77.1451,-52C77.1451,-52 11.9516,-52 11.9516,-52 5.95161,-52 -0.0483924,-46 -0.0483924,-40 -0.0483924,-40 -0.0483924,-28 -0.0483924,-28 -0.0483924,-22 5.95161,-16 11.9516,-16 11.9516,-16 77.1451,-16 77.1451,-16 83.1451,-16 89.1451,-22 89.1451,-28 89.1451,-28 89.1451,-40 89.1451,-40 89.1451,-46 83.1451,-52 77.1451,-52"/>
# <text text-anchor="middle" x="44.5483" y="-29.8" font-family="Times,serif" font-size="14.00">_input_name</text>
# </g>
# <!-- _input_name&#45;&gt;Path(x=_scale_name, y=&#39;fused&#39;) -->
# <g id="edge1" class="edge"><title>_input_name&#45;&gt;Path(x=_scale_name, y=&#39;fused&#39;)</title>
# <path fill="none" stroke="black" d="M89.1809,-34C100.584,-34 112.753,-34 123.734,-34"/>
# <polygon fill="black" stroke="black" points="123.834,-37.5001 133.834,-34 123.834,-30.5001 123.834,-37.5001"/>
# </g>
# </g>
# </svg>
# </div>
# <div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#80b1d3;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Add</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#fdb462;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">Scale</div></div><div style="margin:2px;width:100px;height:15px;display:inline-block;line-height:15px;background-color:#b3de69;border-radius:9px;border-style:solid;border-width:1px;"><div style="width:90%;margin:auto;font-size:9px;text-align:center;overflow:hidden;">AddScale</div></div><div style="min-width: 133pt"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="133pt" height="54pt"
#  viewBox="0.00 0.00 133.00 53.68" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.400602 0.400602) rotate(0) translate(4 130)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-130 328,-130 328,4 -4,4"/>
# <g id="clust1" class="cluster"><title>cluster_E</title>
# <path fill="#777777" fill-opacity="0.266667" stroke="black" d="M184,-8C184,-8 230,-8 230,-8 236,-8 242,-14 242,-20 242,-20 242,-70 242,-70 242,-76 236,-82 230,-82 230,-82 184,-82 184,-82 178,-82 172,-76 172,-70 172,-70 172,-20 172,-20 172,-14 178,-8 184,-8"/>
# <text text-anchor="middle" x="207" y="-66.8" font-family="Times,serif" font-size="14.00">E</text>
# </g>
# <!-- A -->
# <g id="node1" class="node"><title>A</title>
# <g id="a_node1"><a xlink:title="A Add {}">
# <path fill="#80b1d3" stroke="black" d="M132,-89C132,-89 102,-89 102,-89 96,-89 90,-83 90,-77 90,-77 90,-65 90,-65 90,-59 96,-53 102,-53 102,-53 132,-53 132,-53 138,-53 144,-59 144,-65 144,-65 144,-77 144,-77 144,-83 138,-89 132,-89"/>
# <text text-anchor="middle" x="117" y="-66.8" font-family="Times,serif" font-size="14.00">A</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node2" class="node"><title>B</title>
# <g id="a_node2"><a xlink:title="B Scale {}">
# <path fill="#fdb462" stroke="black" d="M222,-126C222,-126 192,-126 192,-126 186,-126 180,-120 180,-114 180,-114 180,-102 180,-102 180,-96 186,-90 192,-90 192,-90 222,-90 222,-90 228,-90 234,-96 234,-102 234,-102 234,-114 234,-114 234,-120 228,-126 222,-126"/>
# <text text-anchor="middle" x="207" y="-103.8" font-family="Times,serif" font-size="14.00">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge2" class="edge"><title>A&#45;&gt;B</title>
# <path fill="none" stroke="black" d="M144.403,-82.1012C152.657,-85.5716 161.9,-89.4578 170.665,-93.1431"/>
# <polygon fill="black" stroke="black" points="169.344,-96.3846 179.919,-97.0341 172.057,-89.9318 169.344,-96.3846"/>
# </g>
# <!-- E/fused -->
# <g id="node4" class="node"><title>E/fused</title>
# <g id="a_node4"><a xlink:title="E/fused AddScale {}">
# <path fill="#b3de69" stroke="black" d="M222,-52C222,-52 192,-52 192,-52 186,-52 180,-46 180,-40 180,-40 180,-28 180,-28 180,-22 186,-16 192,-16 192,-16 222,-16 222,-16 228,-16 234,-22 234,-28 234,-28 234,-40 234,-40 234,-46 228,-52 222,-52"/>
# <text text-anchor="middle" x="207" y="-29.8" font-family="Times,serif" font-size="14.00">fused</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E/fused -->
# <g id="edge4" class="edge"><title>A&#45;&gt;E/fused</title>
# <path fill="none" stroke="black" d="M144.403,-59.8988C152.657,-56.4284 161.9,-52.5422 170.665,-48.8569"/>
# <polygon fill="black" stroke="black" points="172.057,-52.0682 179.919,-44.9659 169.344,-45.6154 172.057,-52.0682"/>
# </g>
# <!-- C -->
# <g id="node3" class="node"><title>C</title>
# <g id="a_node3"><a xlink:title="C Add {}">
# <path fill="#80b1d3" stroke="black" d="M312,-126C312,-126 282,-126 282,-126 276,-126 270,-120 270,-114 270,-114 270,-102 270,-102 270,-96 276,-90 282,-90 282,-90 312,-90 312,-90 318,-90 324,-96 324,-102 324,-102 324,-114 324,-114 324,-120 318,-126 312,-126"/>
# <text text-anchor="middle" x="297" y="-103.8" font-family="Times,serif" font-size="14.00">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g id="edge3" class="edge"><title>B&#45;&gt;C</title>
# <path fill="none" stroke="black" d="M234.403,-108C242.393,-108 251.311,-108 259.824,-108"/>
# <polygon fill="black" stroke="black" points="259.919,-111.5 269.919,-108 259.919,-104.5 259.919,-111.5"/>
# </g>
# <!-- input -->
# <g id="node5" class="node"><title>input</title>
# <path fill="#ffffff" stroke="black" d="M42,-89C42,-89 12,-89 12,-89 6,-89 0,-83 0,-77 0,-77 0,-65 0,-65 0,-59 6,-53 12,-53 12,-53 42,-53 42,-53 48,-53 54,-59 54,-65 54,-65 54,-77 54,-77 54,-83 48,-89 42,-89"/>
# <text text-anchor="middle" x="27" y="-66.8" font-family="Times,serif" font-size="14.00">input</text>
# </g>
# <!-- input&#45;&gt;A -->
# <g id="edge1" class="edge"><title>input&#45;&gt;A</title>
# <path fill="none" stroke="black" d="M54.4029,-71C62.3932,-71 71.3106,-71 79.8241,-71"/>
# <polygon fill="black" stroke="black" points="79.919,-74.5001 89.919,-71 79.919,-67.5001 79.919,-74.5001"/>
# </g>
# </g>
# </svg>
# </div>
